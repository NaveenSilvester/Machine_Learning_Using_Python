# %%
import pandas as pd

# %%
ipl_auction_df = pd.read_csv('IPL IMB381IPL2013.csv')

# %%
ipl_auction_df
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
ipl_auction_df.head(5)
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
ipl_auction_df.columns
# Out:
# Index(['Sl.NO.', 'PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE',
#        'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#        'SOLD PRICE'],
#       dtype='object')

# %%
list(ipl_auction_df.columns)
# Out:
# ['Sl.NO.',
#  'PLAYER NAME',
#  'AGE',
#  'COUNTRY',
#  'TEAM',
#  'PLAYING ROLE',
#  'T-RUNS',
#  'T-WKTS',
#  'ODI-RUNS-S',
#  'ODI-SR-B',
#  'ODI-WKTS',
#  'ODI-SR-BL',
#  'CAPTAINCY EXP',
#  'RUNS-S',
#  'HS',
#  'AVE',
#  'SR-B',
#  'SIXERS',
#  'RUNS-C',
#  'WKTS',
#  'AVE-BL',
#  'ECON',
#  'SR-BL',
#  'AUCTION YEAR',
#  'BASE PRICE',
#  'SOLD PRICE']

# %%
list(ipl_auction_df.columns)
len(list(ipl_auction_df.columns))
# Out:
# 26

# %%
ipl_auction_df.head(5).transpose()
# Out:
#                          0             1            2          3             4
# Sl.NO.                   1             2            3          4             5
# PLAYER NAME    Abdulla, YA  Abdur Razzak  Agarkar, AB  Ashwin, R  Badrinath, S
# AGE                      2             2            2          1             2
# COUNTRY                 SA           BAN          IND        IND           IND
# TEAM                  KXIP           RCB          KKR        CSK           CSK
# PLAYING ROLE    Allrounder        Bowler       Bowler     Bowler       Batsman
# T-RUNS                   0           214          571        284            63
# T-WKTS                   0            18           58         31             0
# ODI-RUNS-S               0           657         1269        241            79
# ODI-SR-B               0.0         71.41        80.62      84.56         45.93
# ODI-WKTS                 0           185          288         51             0
# ...

# %%
ipl_auction_df.shape
# Out:
# (130, 26)

# %%
ipl_auction_df.info
# Out:
# <bound method DataFrame.info of      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
ipl_auction_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %%
ipl_auction_df[0:5]
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
ipl_auction_df[-5:]
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 125           0      0.00  ...  125.64       2       0     0    0.00  0.00
# 126        6814     75.78  ...   42.85       0       0     0    0.00  0.00
# 127        8051     87.58  ...  131.88      67     569    23   24.74  7.02
# 128         790     73.55  ...   91.67       1    1783    65   27.43  7.75
# 129         343     95.81  ...  122.22       0      99     2   49.50  9.00
#
#      SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
ipl_auction_df[['PLAYER NAME', 'COUNTRY']][0:5]
# Out:
#     PLAYER NAME COUNTRY
# 0   Abdulla, YA      SA
# 1  Abdur Razzak     BAN
# 2   Agarkar, AB     IND
# 3     Ashwin, R     IND
# 4  Badrinath, S     IND

# %%
ipl_auction_df[0:5][['PLAYER NAME', 'COUNTRY']]
# Out:
#     PLAYER NAME COUNTRY
# 0   Abdulla, YA      SA
# 1  Abdur Razzak     BAN
# 2   Agarkar, AB     IND
# 3     Ashwin, R     IND
# 4  Badrinath, S     IND

# %%
ipl_auction_df[0:3]
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# 0  13.93          2009       50000       50000
# 1   0.00          2008       50000       50000
# 2  24.90          2008      200000      350000
#
# [3 rows x 26 columns]

# %%
ipl_auction_df.iloc[4:9,1:4]
# Out:
#      PLAYER NAME  AGE COUNTRY
# 4   Badrinath, S    2     IND
# 5     Bailey, GJ    2     AUS
# 6      Balaji, L    2     IND
# 7  Bollinger, DE    2     AUS
# 8       Botha, J    2      SA

# %%
ipl_auction_df.COUNTRY.value_counts()
# Out:
# COUNTRY
# IND    53
# AUS    22
# SA     16
# SL     12
# PAK     9
# NZ      7
# WI      6
# ENG     3
# BAN     1
# ZIM     1
# Name: count, dtype: int64

# %%
ipl_auction_df.value_counts()
# Out:
# Sl.NO.  PLAYER NAME    AGE  COUNTRY  TEAM  PLAYING ROLE  T-RUNS  T-WKTS  ODI-RUNS-S  ODI-SR-B  ODI-WKTS  ODI-SR-BL  CAPTAINCY EXP  RUNS-S  HS   AVE    SR-B    SIXERS  RUNS-C  WKTS  AVE-BL  ECON   SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# 1       Abdulla, YA    2    SA       KXIP  Allrounder    0       0       0           0.00      0         0.0        0              0       0    0.00   0.00    0       307     15    20.47   8.90   13.93  2009          50000       50000         1
# 98      Sharma, RG     1    IND      DC+   Batsman       0       0       1961        78.85     8         59.1       0              1975    109  31.35  129.17  82      408     14    29.14   8.00   21.86  2008          150000      750000        1
# 96      Sharma, I      1    IND      KKR+  Bowler        432     133     47          34.05     64        33.6       0              37      9    9.25   80.43   1       1176    36    32.67   7.63   23.61  2008          150000      950000        1
# ...

# %%
ipl_auction_df.COUNTRY.value_counts(normalize = True) *100
# Out:
# COUNTRY
# IND    40.769231
# AUS    16.923077
# SA     12.307692
# SL      9.230769
# PAK     6.923077
# NZ      5.384615
# WI      4.615385
# ENG     2.307692
# BAN     0.769231
# ZIM     0.769231
# Name: proportion, dtype: float64

# %%
a = ipl_auction_df.value_counts()

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
type(ipl_auction_df)
# Out:
# pandas.core.frame.DataFrame

# %%
ipl_auction_df.iloc[0:3,1:5]
# Out:
#     PLAYER NAME  AGE COUNTRY  TEAM
# 0   Abdulla, YA    2      SA  KXIP
# 1  Abdur Razzak    2     BAN   RCB
# 2   Agarkar, AB    2     IND   KKR

# %%
ipl_auction_df.iloc[1:5,0:5].value_counts()
# Out:
# Sl.NO.  PLAYER NAME   AGE  COUNTRY  TEAM
# 2       Abdur Razzak  2    BAN      RCB     1
# 3       Agarkar, AB   2    IND      KKR     1
# 4       Ashwin, R     1    IND      CSK     1
# 5       Badrinath, S  2    IND      CSK     1
# Name: count, dtype: int64

# %%
ipl_auction_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %%
ipl_auction_df.COUNTRY.value_counts(normalize=True) * 100
# Out:
# COUNTRY
# IND    40.769231
# AUS    16.923077
# SA     12.307692
# SL      9.230769
# PAK     6.923077
# NZ      5.384615
# WI      4.615385
# ENG     2.307692
# BAN     0.769231
# ZIM     0.769231
# Name: proportion, dtype: float64

# %%
ipl_auction_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %%
ipl_auction_df.shape
# Out:
# (130, 26)

# %%
ipl_auction_df.value_counts()
# Out:
# Sl.NO.  PLAYER NAME    AGE  COUNTRY  TEAM  PLAYING ROLE  T-RUNS  T-WKTS  ODI-RUNS-S  ODI-SR-B  ODI-WKTS  ODI-SR-BL  CAPTAINCY EXP  RUNS-S  HS   AVE    SR-B    SIXERS  RUNS-C  WKTS  AVE-BL  ECON   SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# 1       Abdulla, YA    2    SA       KXIP  Allrounder    0       0       0           0.00      0         0.0        0              0       0    0.00   0.00    0       307     15    20.47   8.90   13.93  2009          50000       50000         1
# 98      Sharma, RG     1    IND      DC+   Batsman       0       0       1961        78.85     8         59.1       0              1975    109  31.35  129.17  82      408     14    29.14   8.00   21.86  2008          150000      750000        1
# 96      Sharma, I      1    IND      KKR+  Bowler        432     133     47          34.05     64        33.6       0              37      9    9.25   80.43   1       1176    36    32.67   7.63   23.61  2008          150000      950000        1
# ...

# %%
ipl_auction_df.COUNTRY.value_counts()
# Out:
# COUNTRY
# IND    53
# AUS    22
# SA     16
# SL     12
# PAK     9
# NZ      7
# WI      6
# ENG     3
# BAN     1
# ZIM     1
# Name: count, dtype: int64

# %%
ipl_auction_df.COUNTRY.value_counts(normalize=True)*100
# Out:
# COUNTRY
# IND    40.769231
# AUS    16.923077
# SA     12.307692
# SL      9.230769
# PAK     6.923077
# NZ      5.384615
# WI      4.615385
# ENG     2.307692
# BAN     0.769231
# ZIM     0.769231
# Name: proportion, dtype: float64

# %%
ipl_auction_df[["COUNTRY", "AGE"]][1:10]
# Out:
#   COUNTRY  AGE
# 1     BAN    2
# 2     IND    2
# 3     IND    1
# 4     IND    2
# 5     AUS    2
# 6     IND    2
# 7     AUS    2
# 8      SA    2
# 9      SA    2

# %%
pd.crosstab(ipl_auction_df['COUNTRY'], ipl_auction_df['PLAYING ROLE'])
# Out:
# PLAYING ROLE  Allrounder  Batsman  Bowler  W. Keeper
# COUNTRY
# AUS                    6        9       6          1
# BAN                    0        0       1          0
# ENG                    2        1       0          0
# IND                    7       18      23          5
# NZ                     4        2       0          1
# PAK                    2        2       4          1
# SA                     7        3       4          2
# SL                     4        2       5          1
# WI                     3        2       1          0
# ZIM                    0        0       0          1

# %%
ipl_auction_df[['PLAYER NAME', 'SOLD PRICE']].sort_values('SOLD PRICE', ascending = False)
# Out:
#        PLAYER NAME  SOLD PRICE
# 93       Sehwag, V     1800000
# 127   Yuvraj Singh     1800000
# 50        Kohli, V     1800000
# 111  Tendulkar, SR     1800000
# 113     Tiwary, SS     1600000
# ..             ...         ...
# 34   Henriques, MC       50000
# 5       Bailey, GJ       50000
# 0      Abdulla, YA       50000
# 46     Kamran Khan       24000
# 73      Noffke, AA       20000
#
# [130 rows x 2 columns]

# %%
ipl_auction_df['premium'] = ipl_auction_df['SOLD PRICE'] - ipl_auction_df['BASE PRICE']

# %%
ipl_auction_df
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
ipl_auction_df[['PLAYER NAME', 'TEAM','premium', 'SOLD PRICE']].sort_values('SOLD PRICE', ascending=False)[0:130]
# Out:
#        PLAYER NAME   TEAM  premium  SOLD PRICE
# 93       Sehwag, V     DD  1400000     1800000
# 127   Yuvraj Singh  KXIP+  1400000     1800000
# 50        Kohli, V    RCB  1650000     1800000
# 111  Tendulkar, SR     MI  1400000     1800000
# 113     Tiwary, SS    MI+  1500000     1600000
# ..             ...    ...      ...         ...
# 34   Henriques, MC   KKR+        0       50000
# 5       Bailey, GJ    CSK        0       50000
# 0      Abdulla, YA   KXIP        0       50000
# 46     Kamran Khan    RR+     4000       24000
# 73      Noffke, AA    RCB        0       20000
#
# [130 rows x 4 columns]

# %%
ipl_auction_df.sort_values('SOLD PRICE', ascending = False)
# Out:
#      Sl.NO.    PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 93       94      Sehwag, V    2     IND     DD      Batsman    8178      40
# 127     128   Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 50       51       Kohli, V    1     IND    RCB      Batsman     491       0
# 111     112  Tendulkar, SR    3     IND     MI      Batsman   15470      45
# 113     114     Tiwary, SS    1     IND    MI+      Batsman       0       0
# ..      ...            ...  ...     ...    ...          ...     ...     ...
# 34       35  Henriques, MC    1     AUS   KKR+   Allrounder       0       0
# 5         6     Bailey, GJ    2     AUS    CSK      Batsman       0       0
# 0         1    Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 46       47    Kamran Khan    1     IND    RR+       Bowler       0       0
# 73       74     Noffke, AA    2     AUS    RCB   Allrounder       0       0
#
# ...

# %%
pd.crosstab(ipl_auction_df["TEAM"],ipl_auction_df["AGE"])
# Out:
# AGE    1   2  3
# TEAM
# CSK    3   8  3
# CSK+   0   4  1
# DC     0   5  2
# DC+    2   4  4
# DD     1   4  1
# DD+    0   9  1
# KKR    0   3  2
# KKR+   3   6  3
# KXI+   0   1  0
# KXIP   1   3  1
# KXIP+  0   7  0
# MI     0   3  3
# MI+    1   5  0
# RCB    2   3  4
# RCB+   1  10  1
# RR     0   4  2
# RR+    2   7  0

# %%
ipl_auction_df.groupby("AGE")["SOLD PRICE"].mean()
# Out:
# AGE
# 1    720250.000000
# 2    484534.883721
# 3    520178.571429
# Name: SOLD PRICE, dtype: float64

# %%
ipl_auction_df.groupby("AGE")["SOLD PRICE"].median()
# Out:
# AGE
# 1    750000.0
# 2    362500.0
# 3    425000.0
# Name: SOLD PRICE, dtype: float64

# %%
ipl_auction_df.groupby(["AGE", "PLAYING ROLE"])["SOLD PRICE"].median()
# Out:
# AGE  PLAYING ROLE
# 1    Allrounder      675000.0
#      Batsman         750000.0
#      Bowler          500000.0
# 2    Allrounder      350000.0
#      Batsman         675000.0
#      Bowler          350000.0
#      W. Keeper       325000.0
# 3    Allrounder      775000.0
#      Batsman         375000.0
#      Bowler          437500.0
#      W. Keeper       700000.0
# Name: SOLD PRICE, dtype: float64

# %%
ipl_auction_df.groupby(["AGE", "PLAYING ROLE"])["SOLD PRICE"].median().reset_index()
# Out:
#     AGE PLAYING ROLE  SOLD PRICE
# 0     1   Allrounder    675000.0
# 1     1      Batsman    750000.0
# 2     1       Bowler    500000.0
# 3     2   Allrounder    350000.0
# 4     2      Batsman    675000.0
# 5     2       Bowler    350000.0
# 6     2    W. Keeper    325000.0
# 7     3   Allrounder    775000.0
# 8     3      Batsman    375000.0
# 9     3       Bowler    437500.0
# 10    3    W. Keeper    700000.0

# %%
ipl_auction_df[ipl_auction_df["SIXERS"] > 80] [["PLAYER NAME", "AGE", "COUNTRY","SIXERS"]].sort_values("SIXERS", ascending = False)
# Out:
#       PLAYER NAME  AGE COUNTRY  SIXERS
# 26      Gayle, CH    2      WI     129
# 88      Raina, SK    1     IND      97
# 28  Gilchrist, AC    3     AUS      86
# 97     Sharma, RG    1     IND      82
# 82     Pathan, YK    2     IND      81

# %%
mylist = [1,2,3,4,5,6,7,8,9]
even = filter(lambda x : x%2 == 0, mylist)

# %%
print(even)

# %%
print(list(even))
# Out:
# [2, 4, 6, 8]

# %%
square = list(map(lambda x : x * x, mylist))
square
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
autos = pd.read_csv('auto-mpg.data', sep='\s+', header=None)
autos.head(5)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\silve\AppData\Local\Temp\ipykernel_8096\3345200044.py:1: SyntaxWarning: invalid escape sequence '\s'
#   autos = pd.read_csv('auto-mpg.data', sep='\s+', header=None)
#       0  1      2      3       4     5   6  7                          8
# 0  18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1  15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2  18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3  16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4  17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino

# %%
autos.columns = ['mpg','cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year', 'origin', 'name']

# %%
autos.head(5)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0    70
# 1  15.0          8         350.0      165.0  3693.0          11.5    70
# 2  18.0          8         318.0      150.0  3436.0          11.0    70
# 3  16.0          8         304.0      150.0  3433.0          12.0    70
# 4  17.0          8         302.0      140.0  3449.0          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    float64
#  5   acceleration  398 non-null    float64
#  6   year          398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
autos.shape
# Out:
# (398, 9)

# %%
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline

# %%
soldprice_by_age = ipl_auction_df.groupby('AGE')['SOLD PRICE'].mean().reset_index()

# %%
soldprice_by_age
# Out:
#    AGE     SOLD PRICE
# 0    1  720250.000000
# 1    2  484534.883721
# 2    3  520178.571429

# %%
type(soldprice_by_age)
# Out:
# pandas.core.frame.DataFrame

# %%
from scipy import stats
stats.binom.pmf(5,20,0.1)
# Out:
# 0.031921361119954424

# %%
pmf_df = pd.DataFrame({'success' : range(0,21), 'pmf' : list(stats.binom.pmf(range(0,21), 20, 0.1))})

# %%
sn.barplot(x = pmf_df.success, y = pmf_df.pmf)
plt.ylabel('pmf')
plt.xlabel('Number of items returned')
# Out:
# Text(0.5, 0, 'Number of items returned')

# %%
stats.binom.cdf(5,20,0.1)
# Out:
# 0.988746865835491

# %%
1 - stats.binom.cdf(5,20,0.1)
# Out:
# 0.011253134164509015

# %%
mean, var = stats.binom.stats(20,0.1)
print ("Average : ", mean, " Variance : ", var)
# Out:
# Average :  2.0  Variance :  1.8

# %%
help(stats.binom.stats)
# Out:
# Help on method stats in module scipy.stats._distn_infrastructure:
#
# stats(*args, **kwds) method of scipy.stats._discrete_distns.binom_gen instance
#     Some statistics of the given RV.
#
#     Parameters
#     ----------
#     arg1, arg2, arg3,... : array_like
#         The shape parameter(s) for the distribution (see docstring of the
#         instance object for more information)
#     loc : array_like, optional
#         location parameter (default=0)
#     scale : array_like, optional (continuous RVs only)
#         scale parameter (default=1)
#     moments : str, optional
#         composed of letters ['mvsk'] defining which moments to compute:
#         'm' = mean,
#         'v' = variance,
#         's' = (Fisher's) skew,
#         'k' = (Fisher's) kurtosis.
#         (default is 'mv')
#
#     Returns
#     -------
#     stats : sequence
#         of requested moments.

# %%
stats.binom.std(20, 5, 0)
# Out:
# nan

# %%
import math

# %%
math.sqrt(1.8)
# Out:
# 1.3416407864998738

# %%
standardDeviation = math.sqrt(var)

# %%
standardDeviation
# Out:
# 1.3416407864998738
